# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
df = pd.read_csv('students_ai_usage.csv')

# %%
df
# Out:
#     age education_level  study_hours_per_day uses_ai ai_tools_used  \
# 0    19         college                  1.4      No           NaN
# 1    15          school                  3.9     Yes       Copilot
# 2    15          school                  1.9     Yes       Copilot
# 3    15          school                  2.8      No           NaN
# 4    19         college                  2.7      No           NaN
# ..  ...             ...                  ...     ...           ...
# 95   14          school                  4.4      No           NaN
# 96   16          school                  2.2      No           NaN
# 97   19         college                  3.9     Yes        Gemini
# 98   14          school                  2.6      No           NaN
# 99   15          school                  4.9     Yes        Gemini
#
#    purpose_of_ai  grades_before_ai  grades_after_ai  daily_screen_time_hours
# 0            NaN                62               62                        3
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# age                         0
# education_level             0
# study_hours_per_day         0
# uses_ai                     0
# ai_tools_used              60
# purpose_of_ai              60
# grades_before_ai            0
# grades_after_ai             0
# daily_screen_time_hours     0
# dtype: int64

# %%
df.shape
# Out:
# (100, 9)

# %%
df.describe()
# Out:
#               age  study_hours_per_day  grades_before_ai  grades_after_ai  \
# count  100.000000           100.000000         100.00000       100.000000
# mean    16.490000             2.987000          64.77000        68.700000
# std      1.702612             1.145713           6.16909         8.140806
# min     14.000000             1.000000          55.00000        55.000000
# 25%     15.000000             1.975000          59.00000        61.000000
# 50%     16.000000             2.800000          63.00000        69.000000
# 75%     18.000000             4.025000          70.00000        74.000000
# max     19.000000             5.000000          75.00000        89.000000
#
#        daily_screen_time_hours
# count               100.000000
# mean                  4.340000
# std                   1.793479
# min                   2.000000
# 25%                   3.000000
# 50%                   4.000000
# 75%                   6.000000
# max                   7.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['age'].mean()
# Out:
# np.float64(16.49)

# %%
df['study_hours_per_day'].mean()
# Out:
# np.float64(2.986999999999999)

# %%
df.head(2)
# Out:
#    age education_level  study_hours_per_day uses_ai ai_tools_used  \
# 0   19         college                  1.4      No           NaN
# 1   15          school                  3.9     Yes       Copilot
#
#   purpose_of_ai  grades_before_ai  grades_after_ai  daily_screen_time_hours
# 0           NaN                62               62                        3
# 1      Research                56               61                        2

# %% [markdown]
# # Which age group most use ai

# %%
age_gorup = df.groupby('purpose_of_ai')['age'].mean().reset_index()
age_gorup
